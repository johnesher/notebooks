# %% [markdown]
# ## Analyse log file for battery read and batty watchdog kicks

# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt
import subprocess
import time
#import matplotlib.ticker as ticker
#%matplotlib inline

# %%
def read_source(fileSpec):
    with open(fileSpec) as source :
        yield from source

# %%
run_number = 4
filename = 'run %d.log' % run_number
target = r'C:\Temp\Keeler\debugs\m1662\\' + filename
# newLines = read_source(target)
# #wantedLines = drop_unwanted(newLines)
# wantedLines = drop_leaving_appln(newLines, 'a')
# the_data = get_array(wantedLines)
# the_data

# %% [markdown]
# Here we read more conventinally as we want to have linenumbers

# %%
with open(target) as infile:
    Xs, Ys = [], []
    for li_no, line in enumerate(infile.readlines()):
        if 'SUCCESS' in line:
            Xs += [li_no]
            Ys += [1]
        if 'batty' in line:
            Xs += [li_no]
            Ys += [2]
        if 'notifying' in line:
            Xs += [li_no]
            Ys += [3]
        if 'asking' in line:
            Xs += [li_no]
            Ys += [4]
plt.plot(Xs, Ys, 's', marker='.')
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
l += [0]
l
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-86fd1a194f56> in <module>()
#       1
# ----> 2 l += [0]
#       3 l
#
# NameError: name 'l' is not defined
