# %%
# %matplotlib notebook
import numpy as np
import matplotlib.pyplot as plt

dat=[
33.378964,58.589100,
33.523505,57.655491,
33.503601,56.901735,
33.242444,58.196640,
33.209971,57.633129,
32.020535,58.719611,
33.141233,57.966618,
32.185803,57.758761,
32.906633,57.051271,
32.417866,56.158544,
]

arr = np.array(dat)
plt.plot(arr.reshape(10,2))
# Out:
# <img src="data:image/png;base64,..." width="640">
# array([[ 33.378964,  58.5891  ],
#        [ 33.523505,  57.655491],
#        [ 33.503601,  56.901735],
#        [ 33.242444,  58.19664 ],
#        [ 33.209971,  57.633129],
#        [ 32.020535,  58.719611],
#        [ 33.141233,  57.966618],
#        [ 32.185803,  57.758761],
#        [ 32.906633,  57.051271],
#        [ 32.417866,  56.158544]])

# %%
from scipy.optimize import least_squares

def znet(f, cs, ls, cp, lp, rs, rp):
    """Impedance of the network at w rad/s
    Given  series cs, ls in parallel with cp, lp, rp"""
    w = 2 * np.pi * f
    zcs = 1 / (w * cs * 1j)
    zls = w * ls * 1j
    zcp = 1 / (w * cp * 1j)
    zlp = w * lp * 1j
    ys = 1 / (zcs + zls)
    ycp = 1 / zcp
    ylp = 1 / zlp
    yrp = 1 / rp
    yt = ycp + ylp + ys + yrp
    zt = 1 / yt
    zf = rs + zt
    return zf

Fs = np.linspace(10e6, 20e6, 50)
calc_z = znet(Fs, 361e-12, 473e-9, 1211e-12, 126e-9, 2.5, 300)
Zrs, Zis = calc_z.real, calc_z.imag

ubounds = (1e-6,) * 4 + (5, 1000)
lbounds = (0.0,) * 6
res = least_squares(
                residuals_znet,
                x0=(361e-12, 473e-9, 1211e-12, 126e-9, 2.5, 300),
                args=(Fs, Zrs, Zis),
                bounds=(lbounds, ubounds)
            )



# import sympy as sp
# sp.init_printing()
# I = sp.I
# w1, x1, w2, x2 = sp.symbols('w1 x1 w2 x2')
# sz10 = w1*sl + 1/(w1*sc)
# sz15 = w2*sl + 1/(w2*sc)
# sL, sC = sp.solve([sz10-x1, sz15-x2], [sl, sc])[0]
# L = sL.subs({
#     w1:2 * 3.1415 * 10e6,
#     x1:5 -14.1j,
#     w2:2 * 3.1415 * 15e6,
#     x2:5 + 15.4j
# })
# C = sC.subs({
#     w1:2 * 3.1415 * 10e6,
#     x1:5 -14.1j,
#     w2:2 * 3.1415 * 15e6,
#     x2:5 + 15.4j
# })
# print('L=%.3fnH, C=%.3fpF' % (sp.im(L)*1e9, sp.im(C)*1e12))
# print('resonance %fMHz' % (1e-6/(2*3.14159*(sp.im(L) * sp.im(C))**0.5)))
# sL, sC
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-22-b966fe98fa71> in <module>()
#      25 lbounds = (0.0,) * 6
#      26 res = least_squares(
# ---> 27                 residuals_znet,
#      28                 x0=(361e-12, 473e-9, 1211e-12, 126e-9, 2.5, 300),
#      29                 args=(Fs, Zrs, Zis),
#
# NameError: name 'residuals_znet' is not defined

# %%
f, cs, ls, cp, lp, rs, rp = sp.symbols('f, cs, ls, cp, lp, rs, rp')
w = 2 * 3.14 * f
zcs = 1 / (w * cs * 1j)
zls = w * ls * 1j
zcp = 1 / (w * cp * 1j)
zlp = w * lp * 1j
ys = 1 / (zcs + zls)
ycp = 1 / zcp
ylp = 1 / zlp
yrp = 1 / rp
yt = ycp + ylp + ys + yrp
zt = 1 / yt
zf = rs + zt
zf

zoff = zf.subs({
#    f:20e6,
    cs:361e-12,
    ls:473e-9,
    cp:1211e-12,
    lp:126e-9,
    rs:2.5,
    rp:300
})

sp.diff(zf, lp)
sp.plot(abs(zoff), (f, 10e6, 20e6))
sp.plot(sp.re(zoff), (f, 10e6, 20e6))
sp.plot(sp.im(zoff), (f, 10e6, 20e6))
# Out:
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">
# <img src="data:image/png;base64,..." width="640">

# %%
sp.im(zoff)
# Out:
#
#
#
#
#                                                                            -7.
#
#
#
#
#
# ──────────────────────────────────────────────────────────────────────────────
#
# ⎛
# ⎜                                                                     -2.97044
# ⎜
# ⎜                   1263775.14912547⋅re(f)
# ⎜7.60508e-9⋅re(f) - ────────────────────── + ─────────────────────────────────
# ⎜                        2        2
# ⎜                      re (f) + im (f)       ⎛                   441096035.428
# ⎜                                            ⎜2.97044e-6⋅re(f) - ─────────────
# ⎜                                            ⎜                        2
# ⎝                                            ⎝                      re (f) + i
#
#
#                                                                    -2.97044e-6
#
#                  1263775.14912547⋅re(f)
# 60508e-9⋅re(f) + ────────────────────── - ────────────────────────────────────
#                       2        2
#                     re (f) + im (f)       ⎛                   441096035.428834
#                                           ⎜2.97044e-6⋅re(f) - ────────────────
#                                           ⎜                        2        2
#                                           ⎝                      re (f) + im (
# ──────────────────────────────────────────────────────────────────────────────
#                                                             2
#             441096035.428834⋅re(f)                         ⎞    ⎛
# e-6⋅re(f) + ──────────────────────                         ⎟    ⎜
#                  2        2                                ⎟    ⎜
#                re (f) + im (f)                             ⎟    ⎜
# ───────────────────────────────────────────────────────────⎟  + ⎜-7.60508e-9⋅i
#           2                                               2⎟    ⎜
# 834⋅re(f)⎞    ⎛                    441096035.428834⋅im(f)⎞ ⎟    ⎜
# ─────────⎟  + ⎜-2.97044e-6⋅im(f) - ──────────────────────⎟ ⎟    ⎜
#  2       ⎟    ⎜                         2        2       ⎟ ⎟    ⎜
# m (f)    ⎠    ⎝                       re (f) + im (f)    ⎠ ⎠    ⎝
#
#          441096035.428834⋅re(f)
# ⋅re(f) + ──────────────────────
#               2        2
#             re (f) + im (f)
# ────────────────────────────────────────────────────────
#        2                                               2
# ⋅re(f)⎞    ⎛                    441096035.428834⋅im(f)⎞
# ──────⎟  + ⎜-2.97044e-6⋅im(f) - ──────────────────────⎟
#       ⎟    ⎜                         2        2       ⎟
# f)    ⎠    ⎝                       re (f) + im (f)    ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                                -2.97044e-6⋅im(
#
#         1    1263775.14912547⋅im(f)
# m(f) + ─── - ────────────────────── + ────────────────────────────────────────
#        300        2        2
#                 re (f) + im (f)       ⎛                   441096035.428834⋅re(
#                                       ⎜2.97044e-6⋅re(f) - ────────────────────
#                                       ⎜                        2        2
#                                       ⎝                      re (f) + im (f)
#
#
#
#
#
#
#
#
#
#
#
# ──────────────────────────────────────────────────────
#                                                      2
#      441096035.428834⋅im(f)                         ⎞
# f) - ──────────────────────                         ⎟
#           2        2                                ⎟
#         re (f) + im (f)                             ⎟
# ────────────────────────────────────────────────────⎟
#    2                                               2⎟
# f)⎞    ⎛                    441096035.428834⋅im(f)⎞ ⎟
# ──⎟  + ⎜-2.97044e-6⋅im(f) - ──────────────────────⎟ ⎟
#   ⎟    ⎜                         2        2       ⎟ ⎟
#   ⎠    ⎝                       re (f) + im (f)    ⎠ ⎠
