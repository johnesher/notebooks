# %%
import numpy as np
from scipy.interpolate import UnivariateSpline

def make_norm_dist(x, mean, sd):
    return 1.0/(sd*np.sqrt(2*np.pi))*np.exp(-(x - mean)**2/(2*sd**2))

x = np.linspace(10, 110, 20)
green = make_norm_dist(x, 40, 30)
pink = make_norm_dist(x, 60, 10)

blue = green + pink   

# create a spline of x and blue-np.max(blue)/2 
spline = UnivariateSpline(x, blue-np.max(blue)/2, s=0)
r1, r2 = spline.roots() # find the roots

import pylab as pl
pl.plot(x, blue-np.max(blue)/2)
pl.axvspan(r1, r2, facecolor='g', alpha=0.5)
pl.show()
spline.get_coeffs()
# Out:
# array([-0.0168255 , -0.01587795, -0.01447546, -0.01289047, -0.01169787,
#        -0.00972209, -0.00508532,  0.00426705,  0.01712872,  0.02669541,
#         0.02543766,  0.01345395, -0.00154186, -0.01259668, -0.01840785,
#        -0.02099412, -0.02225669, -0.02331125, -0.02377417, -0.02401713])
