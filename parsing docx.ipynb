# %%
import docx

# %%
#file_spec = r'C:\Temp\Keeler\TonoPuff30a.docx'
file_spec = r'C:\Temp\Keeler\Document.docx'

# %%
def iter_headings(paragraphs):
    for paragraph in paragraphs:
        if paragraph.style.name.startswith('Heading'):
            yield paragraph

document = docx.Document(file_spec)
counter = 1
for heading in iter_headings(document.paragraphs):
    print(dir(heading.part))
    1/0
    print(counter, heading.text, heading.style, heading.part, heading.runs, '\n')
    counter += 1
# Out:
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', '_blob', '_content_type', '_element', '_package', '_partname', '_rel_ref_count', '_rels', '_settings_part', '_styles_part', 'after_unmarshal', 'before_marshal', 'blob', 'content_type', 'core_properties', 'document', 'drop_rel', 'element', 'get_or_add_image', 'get_style', 'get_style_id', 'inline_shapes', 'load', 'load_rel', 'new_pic_inline', 'next_id', 'numbering_part', 'package', 'part', 'part_related_by', 'partname', 'relate_to', 'related_parts', 'rels', 'save', 'settings', 'styles', 'target_ref']
# ---------------------------------------------------------------------------
# ...

# %%
document = docx.Document(file_spec)
body_element = document._body._body
#print(body_element.xml)  # this will be big if your document is

from docx.text.paragraph import Paragraph

ps = body_element.xpath(r'./w:something/w:something_child/w:p')
paragraphs = [Paragraph(p, None) for p in ps]

# %%
import docx2txt
my_text = docx2txt.process(file_spec)
print(my_text)
# Out:
# Ophthalmic Instruments
#
#
#
#
#
#
#
# Ophthalmic Instruments
#
#
#
# TonoPuff System Test Procedure
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# Document
#
# System Test Procedure
#
# Project No
#
# Project 233 – TonoPuff
#
#
#
# Name
#
# Signature
#
# Date
#
# Approval
#
#
#
# R&D Director
#
#
#
#
#
#
#
#
#
# Revision History
#
# Issue
#
# Date
#
# Notes
#
# Author
#
# 1
#
# 14/11/2016
#
# Initial version
#
# S Menon
#
# 2
#
# 30/1/2017
#
# Updated to match latest requirements
#
# -Updated 3.5
#
# -Removed 3.4.3, test for Bad reading, as under new measurement rules, that’s no longer applicable
#
# -Added 3.7.6
#
# - Added 3.8
#
#
#
#
#
# S Menon
#
# 2.1
#
# 17/02/2017
#
# Updated 3.4.5, and 3.4.6 for new CCT Interface
#
# Deleted test under 3.4.4 for easy mode
#
#
#
# D Henley
#
# 2.2
#
# 08/03/2017
#
# Updated 3.2 Calibration tests to reflect changes to workflow.
#
# Updated 3.3 to further clarify menu instructions.
#
# D Henley
#
# 2.3
#
# 21/03/2017
#
# Updated 3.5, 3.3.7, 3.7.3
#
# ...

# %%
import zipfile
zipfile.is_zipfile(file_spec)
zf = zipfile.ZipFile(file_spec)
zf.read('word/document.xml')
# Out:
# b'<?xml version="1.0" encoding="UTF-8" standalone="yes"?>\r\n<w:document xmlns:wpc="http://schemas.microsoft.com/office/word/2010/wordprocessingCanvas" xmlns:mc="http://schemas.openxmlformats.org/markup-compatibility/2006" xmlns:o="urn:schemas-microsoft-com:office:office" xmlns:r="http://schemas.openxmlformats.org/officeDocument/2006/relationships" xmlns:m="http://schemas.openxmlformats.org/officeDocument/2006/math" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:wp14="http://schemas.microsoft.com/office/word/2010/wordprocessingDrawing" xmlns:wp="http://schemas.openxmlformats.org/drawingml/2006/wordprocessingDrawing" xmlns:w10="urn:schemas-microsoft-com:office:word" xmlns:w="http://schemas.openxmlformats.org/wordprocessingml/2006/main" xmlns:w14="http://schemas.microsoft.com/office/word/2010/wordml" xmlns:w15="http://schemas.microsoft.com/office/word/2012/wordml" xmlns:wpg="http://schemas.microsoft.com/office/word/2010/wordprocessingGroup" xmlns:wpi="http://schemas.microsoft.com/office
# ...

# %%
dir(document.tables[0])
dir(heading.part)
heading.part.target_ref()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-58-1d2884d03b44> in <module>()
#       1 dir(document.tables[0])
#       2 dir(heading.part)
# ----> 3 heading.part.target_ref()
#
# TypeError: target_ref() missing 1 required positional argument: 'rId'

# %%
import zipfile

def get_word_xml(docx_filename):
    zip = zipfile.ZipFile(docx_filename)
    xml_content = zip.read('word/document.xml')
    return xml_content

from lxml import etree

def get_xml_tree(xml_string):
   return etree.fromstring(xml_string)

xmltree = get_xml_tree(get_word_xml(file_spec))
es = etree.tostring(xmltree, pretty_print=True)
print(es)
# Out:
# b'<w:document xmlns:wpc="http://schemas.microsoft.com/office/word/2010/wordprocessingCanvas" xmlns:mc="http://schemas.openxmlformats.org/markup-compatibility/2006" xmlns:o="urn:schemas-microsoft-com:office:office" xmlns:r="http://schemas.openxmlformats.org/officeDocument/2006/relationships" xmlns:m="http://schemas.openxmlformats.org/officeDocument/2006/math" xmlns:v="urn:schemas-microsoft-com:vml" xmlns:wp14="http://schemas.microsoft.com/office/word/2010/wordprocessingDrawing" xmlns:wp="http://schemas.openxmlformats.org/drawingml/2006/wordprocessingDrawing" xmlns:w10="urn:schemas-microsoft-com:office:word" xmlns:w="http://schemas.openxmlformats.org/wordprocessingml/2006/main" xmlns:w14="http://schemas.microsoft.com/office/word/2010/wordml" xmlns:w15="http://schemas.microsoft.com/office/word/2012/wordml" xmlns:wpg="http://schemas.microsoft.com/office/word/2010/wordprocessingGroup" xmlns:wpi="http://schemas.microsoft.com/office/word/2010/wordprocessingInk" xmlns:wne="http://schemas.mic
# ...
