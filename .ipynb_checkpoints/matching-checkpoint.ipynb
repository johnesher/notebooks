#        'Xs (Ohm)', '|Z| (Ohm)', 'Magnitude', 'SWR', 'Theta',
#        'GroupDelay (nS)'],
#       dtype='object')

# %%
df.plot('Frequency (Hz)', 'Returnloss (dB)', grid=True, kind='line',
                xlim=(1.5e7, 1.8e7))  #, figsize=(7,7));
df.plot('Frequency (Hz)', 'Returnloss (dB)', grid=True, kind='line');
df['Xsoffset'] = df['Xs (Ohm)'] - 20
df.plot('Frequency (Hz)', ['Xs (Ohm)', 'Xsoffset'], grid=True, kind='line', alpha=0.6);
df.plot('Frequency (Hz)', 'Rs (Ohm)', grid=True, kind='line', ylim=(0, 20));

# %%
df.plot('Frequency (Hz)', 'Returnphase (°)', grid=True, kind='line',
                xlim=(1.6e7, 1.7e7), ylim=(-180, 180), figsize=(7,7), marker='o');

# %%
df[df['Frequency (Hz)'] < 12e6]
# Out:
#      Frequency (Hz)  Returnloss (dB)  Returnphase (°)  Transmissionloss (dB)  \
# 0          10000000        -0.476031      -148.367570                      0
# 1          10015822        -0.505160      -148.401537                      0
# 2          10031644        -0.515168      -148.609722                      0
# 3          10047466        -0.514202      -148.895972                      0
# 4          10063288        -0.515984      -148.995818                      0
# 5          10079110        -0.511688      -149.359815                      0
# 6          10094932        -0.534644      -149.401767                      0
# 7          10110754        -0.519275      -149.581118                      0
# 8          10126576        -0.525195      -149.793835                      0
# 9          10142398        -0.523737      -149.961674                      0
# 10         10158220        -0.517038      -150.211107                      0
# 11         10174042        -0.518470      -150.498681                      0
# 12         10189864        -0.512105      -150.615227                      0
# 13         10205686        -0.515516      -150.757155                      0
# 14         10221508        -0.513170      -151.005038                      0
# 15         10237330        -0.512360      -151.258694                      0
# 16         10253152        -0.516643      -151.534416                      0
# 17         10268974        -0.528460      -151.622741                      0
# 18         10284796        -0.515969      -151.908146                      0
# 19         10300618        -0.517747      -152.046836                      0
# 20         10316440        -0.519999      -152.274783                      0
# 21         10332262        -0.527702      -152.501699                      0
# 22         10348084        -0.535024      -152.706268                      0
# 23         10363906        -0.528754      -152.907911                      0
# 24         10379728        -0.529447      -153.161401                      0
# 25         10395550        -0.528621      -153.241957                      0
# 26         10411372        -0.533096      -153.474652                      0
# 27         10427194        -0.532044      -153.730678                      0
# 28         10443016        -0.539508      -153.939707                      0
# 29         10458838        -0.546365      -154.117584                      0
# ..              ...              ...              ...                    ...
# 97         11534734        -0.586354      -167.548472                      0
# 98         11550556        -0.596044      -167.800435                      0
# 99         11566378        -0.598079      -168.021231                      0
# 100        11582200        -0.604792      -168.224261                      0
# 101        11598022        -0.608059      -168.248378                      0
# 102        11613844        -0.601430      -168.554559                      0
# 103        11629666        -0.609781      -168.794386                      0
# 104        11645488        -0.640311      -168.906409                      0
# 105        11661310        -0.622375      -168.944871                      0
# 106        11677132        -0.602817      -169.271512                      0
# 107        11692954        -0.612729      -169.525881                      0
# 108        11708776        -0.610676      -169.604253                      0
# 109        11724598        -0.611034      -169.802899                      0
# 110        11740420        -0.604090      -170.062862                      0
# 111        11756242        -0.608052      -170.303046                      0
# 107  28.363225 -68.775518                0 -24.577222
# 108  28.458497 -68.696787                0 -24.542823
# 109  28.441868 -68.312534                0 -24.455548
# 110  28.768510 -68.033481                0 -24.341504
# 111  28.581240 -67.415022                0 -24.235994
# 112  28.425748 -66.851194                0 -24.142404
# 113  28.222387 -66.176904                0 -24.038684
# 114  28.632556 -66.368018                0 -24.016755
# 115  28.650318 -65.901406                0 -23.925740
# 116  28.660613 -65.299314                0 -23.814920
# 117  28.639937 -64.677747                0 -23.709926
# 118  28.061211 -63.551002                0 -23.600352
# 119  28.592998 -63.657426                0 -23.549394
# 120  28.430325 -62.909939                0 -23.454678
# 121  28.027596 -62.199043                0 -23.399094
# 122  28.556604 -61.826103                0 -23.283118
# 123  27.440723 -60.176151                0 -23.191481
# 124  28.403337 -60.284759                0 -23.096169
# 125  27.802689 -58.745143                0 -22.973578
# 126  28.179162 -58.529070                0 -22.908616
#
# [127 rows x 13 columns]

# %% [markdown]
# Estimated values for X by shifting X values by -20 so the change from cap to ind happens at the resonance rather than at lower frequency.
#
# At 12M impedance is about 1.8-22j (after offset 2 -2.7j)
#
# At 20M impedance is about 11+31j (after offset 2 +6.5j)
#
# $C = \frac{1}{\omega X_C}$
#
# $L = \frac{X_L}{\omega}$

# %%
wc = 2 * 3.1415 * 10e6  # 12e6
C_offset = 1/(wc*2.7)  # 1/(wc*22)
wl = 2 * 3.1415 * 20e6
L_offset = 6.5 / wc  # 31 / wc
w_resonance = (1/(C_offset * L_offset))**0.5
f_resonance = w_resonance / (2 * 3.14159)
print('%.2fnH, %.2fpF, %.2fMHz' % (L_offset * 1e9, C_offset * 1e12, f_resonance / 1e6))
# Out:
# 103.45nH, 5894.80pF, 6.44MHz

# %% [markdown]
# The impedance is really that of the L and C simultaneously. Presume that the circuit is a parallel LC fed by a series resistor. Ignore the resistor and work only with the admittances.
#
# $Y_{LC} = Y_L + Y_C$
#
# We have a different Y at 12M and at 20M. Use these to solve for L and C separately.
#
# $Y_L = \frac{1}{\omega L}$  and  $Y_C = {\omega C}$
#
# $Y_{LC_{10}} = \frac{1}{\omega_{10} L} + {\omega_{10} C}$
#
# $Y_{LC_{20}} = \frac{1}{\omega_{20} L} + {\omega_{20} C}$
#
# $C = \frac{Y_{LC_{10}} - \frac{1}{\omega_{10} L}}{\omega_{10}}$
#
# $C = \frac{Y_{LC_{10}}}  {\omega_{10}} - \frac{1}{{\omega_{10}}^2 L}$
#
# Now substitute into the 20MHz equation
#
# $Y_{LC_{20}} = \frac{1}{\omega_{20} L} + \omega_{20}\left( \frac{Y_{LC_{10}}}  {\omega_{10}} - \frac{1}{{\omega_{10}}^2 L} \right) $
#
# $Y_{LC_{20}} = \frac{1}{\omega_{20} L} + \omega_{20}\frac{Y_{LC_{10}}}{\omega_{10}} - \frac{\omega_{20}}{{\omega_{10}}^2 L}$
#
# $Y_{LC_{20}} - \omega_{20}\frac{Y_{LC_{10}}}{\omega_{10}} = \frac{1}{\omega_{20} L} - \frac{\omega_{20}}{{\omega_{10}}^2 L}$
#
# $L \left(Y_{LC_{20}} - \omega_{20}\frac{Y_{LC_{10}}}{\omega_{10}}\right) = \frac{1}{\omega_{20}} - \frac{\omega_{20}}{{\omega_{10}}^2}$
#
# $L = \frac{\frac{1}{\omega_{20}} - \frac{\omega_{20}}{{\omega_{10}}^2}}
# {Y_{LC_{20}} - \omega_{20}\frac{Y_{LC_{10}}}{\omega_{10}}}$
#
# Divide through by $\omega_{20}$
#
# $L = \frac
# {\frac{1}{{\omega_{20}}^2} - \frac{1}{{\omega_{10}}^2}}
# {\frac{Y_{LC_{20}}}{\omega_{20}} - \frac{Y_{LC_{10}}}{\omega_{10}}}$

# %%
Y20 = 1 / 6.6
Y10 = 1 / -27
w20 =  2 * np.pi * 20e6
w10 = 2 * np.pi * 10e6
denom_L = (1 / w20) - (w20 / w10**2)
num_L = Y20 - w20 * Y10 / w10
L_offset = denom_L / num_L
C_offset = (Y10 / w10) - 1 / (w10**2 * L_offset)
w_resonance = (1/(C_offset * L_offset))**0.5
f_resonance = w_resonance / (2 * 3.14159)
f_resonance = 0
print('%.2fnH, %.2fpF, %.2fMHz' % (L_offset * 1e9, C_offset * 1e12, f_resonance / 1e6))
Ld = 1/w20**2 - 1/w10**2
Ln = Y20/w20 - Y10/w10
L = Ld/Ln
Y10/w10
Y20/w10
# Out:
# -105.83nH, 1804.11pF, 0.00MHz
# 2.411438531695384e-09

# %% [markdown]
# To do this properly need to offset by a time, ie frequency dependent phase. Go back to the measured data of reflected power and phase.
#
# Choose to offset X by 20ohms at 15MHz.
#
# by trial and error this is something like 37.5 deg of phase shift pr 7ns

# %%
time_offset_15e6 =  (37.5/360) * (1 / 15e6)
time_offset_15e6
# Out:
# 6.944444444444445e-09

# %% [markdown]
# Need to be offset phase in phase column so need to convert the rl and phase into s or Z.
#
# $S_{11}$ is simply $\Gamma$, with magnitude $\rho$, and phase $\theta$
#
# The sparam display routine expects s to be in cartesian coords so need to convert the mag and phase to a complex xy.

# %%
df['rho'] = 10**(df['Returnloss (dB)']/20)
from smithplot import SmithAxes


df['phase (rads)'] = np.pi * df['Returnphase (°)'] / 180
df['s11'] = df['rho'] * np.exp(1j * df['phase (rads)'])
df['phase_offsets'] = df['Frequency (Hz)'] * 2 * np.pi * time_offset_15e6
df['s11_offset'] = df['rho'] * np.exp(1j * (df['phase (rads)'] + df['phase_offsets']))
plt.figure(figsize=(9, 9))
ax = plt.subplot(1, 1, 1, projection='smith')
plt.plot(df['s11'], datatype=SmithAxes.S_PARAMETER);
#plt.plot(df['s11_offset'], datatype=SmithAxes.S_PARAMETER);

# %%
df['offset_phase (deg)'] = 0 * (df['phase (rads)'] - df['phase_offsets']) * 180 / np.pi
#df['offset_phase (deg)']
#df['phase_offsets']

# %% [markdown]
# Now convert the offset S params back to Zs.
#
# First convert the original onez to Zs to make sure the equations are correct.

# %%
Z0 = 50
offset_complex_z = Z0 * (1 + df['s11_offset']) / (1 - df['s11_offset'])
original_complex_z = Z0 * (1 + df['s11']) / (1 - df['s11'])
# expecting 1.5 and -14
# %%
10**-(9.6/20)
#df.assign(rho=df['Returnloss (dB)'])
df['rho'] = 10**(df['Returnloss (dB)']/20)
#df['rho']
df.plot('Frequency (Hz)', 'rho', grid=True, kind='line',
                xlim=(1.6e7, 1.7e7), figsize=(7,7), marker='o');
# df = pd.DataFrame({'a': [1, 2], 'b': [3, 4]})
# >>> df.assign(mean_a=df.a.mean(), mean_b=df.b.mean())

# %%
#rs = df['Rs (Ohm)'][df['Frequency (Hz)'] > 16e6]
low_threshold = 16.6e6
high_threshold = 16.8e6
below_resonance = df['Frequency (Hz)'] < low_threshold
above_resonance = df['Frequency (Hz)'] > high_threshold
Rs_below = df['Rs (Ohm)'][below_resonance]
Rs_above = df['Rs (Ohm)'][above_resonance]
Xs_below = df['Xs (Ohm)'][below_resonance]
Xs_above = df['Xs (Ohm)'][above_resonance]
over_16 = df['Frequency (Hz)'] > 16.6e6
under_17 = df['Frequency (Hz)'] < 16.8e6
between_16_17 = over_16 & under_17
Rs = df['Rs (Ohm)'][between_16_17]
#between_16_17
Xs = df['Xs (Ohm)'][between_16_17]

over_18 = df['Frequency (Hz)'] > 18e6
under_15 = df['Frequency (Hz)'] < 15e6
between_16_17 = over_16 & under_17

#Rs_above

# %%
from smithplot import SmithAxes
# plot data
plt.figure(figsize=(9, 9))

ax = plt.subplot(1, 1, 1, projection='smith')
#plt.plot(df['Rs (Ohm)'], df['Xs (Ohm)'], datatype=SmithAxes.Z_PARAMETER);
# plt.plot(Rs_above, Xs_above, datatype=SmithAxes.Z_PARAMETER);
#plt.plot(Rs_below, Xs_below, datatype=SmithAxes.Z_PARAMETER);
#plt.plot(Rs, Xs, datatype=SmithAxes.Z_PARAMETER);
#plt.plot(1+2j, datatype=SmithAxes.S_PARAMETER);
#plt.plot(100 - 75j, datatype=SmithAxes.Z_PARAMETER)

#plt.plot(df['Frequency (Hz)'].values, df['rho'].values, datatype=SmithAxes.S_PARAMETER)


plt.plot(df['Rs (Ohm)'][over_18], df['Xs (Ohm)'][over_18], datatype=SmithAxes.Z_PARAMETER);
plt.plot(df['Rs (Ohm)'][under_15], df['Xs (Ohm)'][under_15], datatype=SmithAxes.Z_PARAMETER);
# Series resonance is at 12.54M, df[161]
df.loc(16)
#df[0:170]
df[under_15][-3:]
# Out:
#      Frequency (Hz)  Returnloss (dB)  Returnphase (°)  Transmissionloss (dB)  \
# 314        14968108        -0.862345       145.992999                      0
# 315        14983930        -0.809243       145.478963                      0
# 316        14999752        -0.843662       145.674253                      0
#
#      Transmissionphase (°)  Rs (Ohm)   Xs (Ohm)  |Z| (Ohm)  Magnitude  \
# 314                      0  2.711277  15.248751  15.487913   0.905488
# 315                      0  2.551670  15.498571  15.707219   0.911041
# 316                      0  2.657182  15.402266  15.629792   0.907438
#
#            SWR      Theta  GroupDelay (nS)  Xsoffset       rho  phase (rads)  \
# 314  20.161357  79.917988                0 -4.751249  0.905488      2.548059
# 315  21.482228  80.650749                0 -4.501429  0.911041      2.539087
# 316  20.607118  80.211744                0 -4.597734  0.907438      2.542495
#
#                                    s11  phase_offsets  \
# 314  (-0.750621780333+0.506434247578j)       0.653107
# 315  (-0.750623099991+0.516294859711j)       0.653797
# 316  (-0.749403036875+0.511701716211j)       0.654488
#
#                              s11_offset  offset_phase (deg)
# 314  (-0.903881827365-0.0539105406165j)                 0.0
# 315  (-0.909842715054-0.0467081820067j)                 0.0
# 316  (-0.906046214192-0.0502375934826j)                 0.0

# %% [markdown]
# ##Some possibilities
# Add series R of 47 with, in parallel, a series LC resonant at the self-resonance. This will modify the resonance and provide (approx) matching at other frequencies.
#
# Match at a frequency away from the resonance.
#
# Damp the resonance to make it more manageable.
#
# Measure both over a wider frequency range (1..100MHz) and also narrower around the resonance (to get better resolution on behaviour there).
#
# What reference plane was used for the measurements?

# %%
from cmath import exp
def P2R(radii, angles):
    return radii * exp(1j*angles)
P2R(0.3, 3.14/2)
# Out:
# (0.000238898013219979+0.29999990487955036j)

# %% [markdown]
# Tapped impedance transformer of 2 Cs and 1 L
#
# $R_L = R_S \left(\frac{C_1 + C_2}{C_1}\right)^2$
#
# The inductor should be close to its max value of
#
# $L_{max} = \frac{R_L}{\omega \sqrt{\frac{R_L}{R_S} - 1}}$

# %%
# Assume C1 = C2 then
Rl = 50 * 4
Rs = 50
w = 2 * 3.1415 * 16e6
Lmax = Rl/(w*(Rl/Rs - 1)**0.5)
Lmax
# Out:
# 1.1486357416632696e-06

# %%
Znorm = (3.5/50, 30/50)
f = 19.75e6
#plt.figure(figsize=(9, 9))
ax = plt.subplot(1, 1, 1, projection='smith')
plt.plot(Znorm, datatype=SmithAxes.Z_PARAMETER);
# Transformer ratio would be 50/3.5 or 14:1 !

# %%
df[df['Returnphase (°)']**2 < 1000]
# Out:
#      Frequency (Hz)  Returnloss (dB)  Returnphase (°)  Transmissionloss (dB)  \
# 424        16708528        -5.217510        29.335107                      0
# 425        16724350        -4.944136        26.437169                      0
# 426        16740172        -4.431828        13.680459                      0
# 427        16755994        -4.204592        -5.209410                      0
# 428        16771816        -4.574776       -24.427983                      0
# 429        16787638        -3.781828        -5.915682                      0
# 430        16803460        -2.275137       -23.377481                      0
#
#      Transmissionphase (°)    Rs (Ohm)    Xs (Ohm)   |Z| (Ohm)  Magnitude  \
# 424                      0  101.464469   77.978867  127.967739   0.548434
# 425                      0  110.784487   82.142823  137.915358   0.565970
# 426                      0  165.025589   73.272888  180.561239   0.600356
# 427                      0  203.561360  -36.730149  206.848571   0.616269
# 428                      0  119.111598  -89.336518  148.891189   0.590556
# 429                      0  221.065578  -50.711679  226.807549   0.647006
# 430                      0  113.619686 -170.162170  204.608400   0.769561
#
#           SWR      Theta  GroupDelay (nS)    Xsoffset       rho  phase (rads)  \
# 424  3.429033  37.543493                0   57.978867  0.548434      0.511994
# 425  3.607973  36.555642                0   62.142823  0.565970      0.461416
# 426  4.004450  23.941664                0   53.272888  0.600356      0.238769
# 427  4.211986 -10.228265                0  -56.730149  0.616269     -0.090921
# 428  3.884675 -36.870766                0 -109.336518  0.590556     -0.426349
# 429  4.665826 -12.919922                0  -70.711679  0.647006     -0.103248
# 430  7.679091 -56.268403                0 -190.162170  0.769561     -0.408014
#
#                                    s11  phase_offsets  \
# 424   (0.478108049641+0.268687062115j)       0.729047
# 425   (0.506782354563+0.251978846513j)       0.729737
# 426   (0.583323471712+0.141988183309j)       0.730428
# 427  (0.613723598971-0.0559548578117j)       0.731118
# 428   (0.537690616323-0.244223997675j)       0.731809
# 429  (0.643560925874-0.0666835825193j)       0.732499
# 430   (0.706388355893-0.305351975769j)       0.733189
#
#                            s11_offset  offset_phase (deg)
# 424  (0.177589180797+0.518885466499j)                -0.0
# 425   (0.20974222842+0.525670896668j)                -0.0
# 426  (0.339778403577+0.494952071732j)                -0.0
# 427  (0.494234391388+0.368130368776j)                -0.0
# 428  (0.563218580622+0.177598959358j)                -0.0
# 429  (0.523084469154+0.380788660047j)                -0.0
# 430  (0.729232095435+0.245855423847j)                -0.0

# %%
df[df['Xs (Ohm)']**2 < 0.01]
# Out:
#      Frequency (Hz)  Returnloss (dB)  Returnphase (°)  Transmissionloss (dB)  \
# 159        12515698        -0.661427      -179.813344                      0
# 160        12531520        -0.653132      -179.935480                      0
# 161        12547342        -0.658179       179.779252                      0
#
#      Transmissionphase (°)  Rs (Ohm)  Xs (Ohm)  |Z| (Ohm)  Magnitude  \
# 159                      0  1.902824 -0.081326   1.904562   0.926678
# 160                      0  1.878981 -0.028112   1.879191   0.927563
# 161                      0  1.893491  0.096182   1.895933   0.927024
#
#            SWR     Theta  GroupDelay (nS)   Xsoffset       rho  phase (rads)  \
# 159  26.276798 -2.447319                0 -20.081326  0.926678     -3.138335
# 160  26.610179 -0.857164                0 -20.028112  0.927563     -3.140467
# 161  26.406344  2.907889                0 -19.903818  0.927024      3.137740
#
#                                      s11  phase_offsets  \
# 159  (-0.926672692547-0.00301889429352j)       0.546100
# 160  (-0.927562358666-0.00104451053841j)       0.546791
# 161   (-0.927017315383+0.0035716127541j)       0.547481
#
#                             s11_offset  offset_phase (deg)
# 159  (-0.790326129996-0.483855351401j)                -0.0
# 160  (-0.791778433502-0.483176916313j)                -0.0
# 161  (-0.793382165701-0.479498277979j)                 0.0

# %%
# Series rlc response
SmithAxes.update_scParams({"grid.minor.enable": False})

Omegas = np.linspace(10e6, 20e6, 10) * 2 * 3.14159
R = 2.0
L = 290e-9
C = 465e-12
Xs = L * Omegas - 1/(C * Omegas)
Rs = np.ones(Omegas.shape) * R
ax = plt.subplot(1, 1, 1, projection='smith')
plt.plot(Rs, Xs, datatype=SmithAxes.Z_PARAMETER);

# %%
# Parallel lc in series with r response
SmithAxes.update_scParams({"grid.minor.enable": False})
Omegas = np.linspace(10e6, 20e6, 20) * 2 * 3.14159
R = 2.0 * 5
L = 290e-9
C = 465e-12
Xcs = -1/(C * Omegas)
Xls = L * Omegas
Xs = 1/(1/Xcs + 1/Xls)
Rs = np.ones(Omegas.shape) * R
ax = plt.subplot(1, 1, 1, projection='smith')
plt.plot(Rs, Xs, datatype=SmithAxes.Z_PARAMETER);

# %%
Omegas[3]/2/3.14
# Out:
# 11584810.593362385

# %%
pi = 3.14159
s_11 = 0.61*exp(1j * 90/180*pi);
# s_21 = 3.72*exp(j*59/180*pi);
# s_12 = 0.05*exp(j*42/180*pi);
# s_22 = 0.45*exp(j*(-48/180)*pi);
s_11
# Out:
# (8.09344886973295e-07+0.6099999999994631j)

# %%
import pylab
import scipy
import skrf

#ntwk = rf.Network('ring slot.s2p')
#ntwk.plot_s_smith()
#skrf.network.z2s(np.array([3 -14j]))
2*3.14159*20e6*3.7e-9
#26/180*3.14
# Out:
# 0.46495532

# %%
# Choose a Z somewhere around 12M (not from real data)
# call it 2 and -25
ax = plt.subplot(1, 1, 1, projection='smith')
plt.plot([2 -25j], datatype=SmithAxes.Z_PARAMETER);
# adding resistance would move it towards the locus of 50ohms
plt.plot([2+48 -25j], datatype=SmithAxes.Z_PARAMETER);
# Now a little series L
plt.plot([2+48 -25j+25j], datatype=SmithAxes.Z_PARAMETER);

# %%
ax = plt.subplot(1, 1, 1, projection='smith')
plt.plot([2 -25j], datatype=SmithAxes.Z_PARAMETER);
# This time add parallel L of 25R
Ylr = 1/(2-25j)
Ynewl = 1/31j
Yt = Ylr + Ynewl
plt.plot([1/Yt], datatype=SmithAxes.Z_PARAMETER);
# Now add series L of +2.5j denorm to 50
plt.plot([(0+115j)+(1/Yt)], datatype=SmithAxes.Z_PARAMETER);
# This is not a good transform - too sensitive to the 31j
# At 12M 31j is 31/w12
31 / (2 * np.pi * 12E6), 115 / (2 * np.pi * 12E6)
# Out:
# (4.1115026965406296e-07, 1.5252348712973304e-06)

# %%
1/(10e6*2*3.14159*14.1)
# Out:
# 1.128759415066938e-09

# %%
15.4/(2*3.1415*15e6)
# Out:
# 1.634038941057881e-07

# %%
10e6*2*3.1415*163e-9
# Out:
# 10.24129

# %%
# starting with series model, calc l and c 
w1=2*3.1415*10e6
x1=-14.1  # @10M
w2=2*3.1415*15e6
x2=15.4  # @15M
c=(w1/w2**.5 - 1/w1) / (x1 - x2*w1/w2)
#c=(w2/w1**.5 - 1/w2) / (x2 - x1*w2/w1)
L = x2/w2 - 1/(c*w2**2)
res_w = (1/(L*c))**.5
res_f = 1 / ( 2 * 3.1415 * (L*c)**.5)
L*1e9, c*1e9, res_f*1e-6
# Out:
# (163.403894106212,
#  -265608383117.18817,
#  (1.4793185606195092e-21-2.4159105493101657e-05j))

# %%
L*w1-1/(c*w1), L*w2-1/(c*w2), x1/w1 - 1/(c*w1**2)
# Out:
# (10.26666666675322, 15.400000000079897, -2.2441508833264486e-07)

# %%
# presume xl is 30 at 15M 
1e9*30/w2
#318nH
# What is this at 10M
w1*(30/w2)
# 20
# so cap has to add -34 at 10M
1e9/(w1*34)
# 468pF
# What's the resonance?
1e-6/(2*3.14159*(318e-9*468e-12/2)**.5)
# 13M
# What's the Z at 10M
# wL - 1/wC
w1*318e-9 - 1/(w1*468e-12/2)
# -14
# and now at 15M
#w2*318e-9 - 1/(w2*468e-12/2)
# only 7.2!!
# Out:
# -48.03699893847323
